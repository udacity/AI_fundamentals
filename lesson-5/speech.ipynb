# %% [markdown]
# Copy your Speech Service Key (`cognitive_key`) and Service Region (`cognitive_service_region`) to the variables listed below.

# %%
cognitive_key = '<YourKey>'
cognitive_service_region = '<YourRegion>'

print('Cognitive services ready at {}'.format(cognitive_service_region))
# Out:
# Cognitive services ready at centralus

# %% [markdown]
# Let's install Azure Speech SDK

# %%
pip install azure.cognitiveservices.speech
# Out:
# Collecting azure.cognitiveservices.speech
#   Using cached azure_cognitiveservices_speech-1.15.0-cp36-cp36m-manylinux1_x86_64.whl (3.1 MB)
# Installing collected packages: azure.cognitiveservices.speech
# Successfully installed azure.cognitiveservices.speech
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Speech Recognition
#
# We have a sample WAV file we want to transcribe into text. The language of the audio file is `en-US`. Complete the code between the two comment lines pointed below.

# %%
import os
import IPython
from azure.cognitiveservices.speech import SpeechConfig, SpeechRecognizer, AudioConfig
import azure.cognitiveservices.speech as speechsdk

file_name = 'speech-sample.wav'
audio_file = file_name

# YOUR CODE STARTS HERE #





#YOUR CODE ENDS HERE #

print(result)

if result.reason == speechsdk.ResultReason.RecognizedSpeech:
    print("Recognized: {}".format(result.text))
elif result.reason == speechsdk.ResultReason.NoMatch:
    print("No speech could be recognized: {}".format(result.no_match_details))
elif result.reason == speechsdk.ResultReason.Canceled:
    cancellation_details = result.cancellation_details
    print("Speech Recognition canceled: {}".format(cancellation_details.reason))
    if cancellation_details.reason == speechsdk.CancellationReason.Error:
        print("Error details: {}".format(cancellation_details.error_details))
# Out:
# SpeechRecognitionResult(result_id=56ff2c8c6d264f47abcf9cda4d52a8d9, text="This is me talking to see how Azure Cognitive Services does speech recognition.", reason=ResultReason.RecognizedSpeech)
# Recognized: This is me talking to see how Azure Cognitive Services does speech recognition.

# %% [markdown]
# ### Speech synthesis
#
# Now we have some text in the `text` variable below, and we want to synthesis speech based on it. Once you are done, use the `file_name` variable to store your file into the storage. Make sure you write your code between the two comment lines pointed below.

# %%
import os
import IPython
from azure.cognitiveservices.speech import SpeechConfig, SpeechRecognizer, AudioConfig
import azure.cognitiveservices.speech as speechsdk

speech_config = speechsdk.SpeechConfig(subscription=cognitive_key, region=cognitive_service_region)
voice = "Microsoft Server Speech Text to Speech Voice (en-US, BenjaminRUS)"
text = " Using Azure Speech to Text Capability"
file_name = "outputaudio.wav"

# YOUR CODE STARTS HERE #

file_name = "outputaudio.wav"
speech_config.speech_synthesis_voice_name = voice
file_config = speechsdk.audio.AudioOutputConfig(filename=file_name)
speech_synthesizer = speechsdk.SpeechSynthesizer(speech_config=speech_config, audio_config=file_config)
result = speech_synthesizer.speak_text_async(text).get()


#YOUR CODE ENDS HERE #

IPython.display.display(IPython.display.Audio(file_name, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Feel free to play with the Speech Synthesizer by changing the `text` variable and playing different outputs.
#
# Finally, delete the `outputaudio.wav` once you are done with the exercise.

# %%
import os
if os.path.exists("outputaudio.wav"):
  os.remove("outputaudio.wav")
